# %%
import numpy as np
import pandas as pd
from pathlib import Path
from googletrans import Translator

# %%
# generate a translated list of columns for every table in the data
data = Path('./vidas_data/')
tabs = pd.read_csv(data / 'table_info.csv')
tabs.head()
# Out:
#      TABLE_CATALOG    TABLE_SCHEMA                      TABLE_NAME  TABLE_TYPE
# 0  wHospital_FX_AI          wH_Spt  Sup_Complicanze_Postoperatorie  BASE TABLE
# 1  wHospital_FX_AI  wH_DirectTable                 NutritionalRisk  BASE TABLE
# 2  wHospital_FX_AI       wH_Vitals           VitalDetection_Delete  BASE TABLE
# 3  wHospital_FX_AI  wH_DigitalSign              DigSigDoc_PubToRep  BASE TABLE
# 4  wHospital_FX_AI   wH_ADIManager                AdiConfiguration  BASE TABLE

# %%
tinfo = pd.read_csv(data/ 'row_and_column_count.csv')
tinfo = tinfo[tinfo.num_rows > 0].reset_index(drop=True)
tinfo['cols'] = ''
tinfo
# Out:
#                               file_name  num_rows  num_columns cols
# 0                        wH_Conf_DBType         7            4
# 1           wH_DirectTable_D_Scala_ESAS         3            5
# 2                  wH_Bck_IsWorking_Bck         1           16
# 3    wH_Core_OperationalUnitAssignation      3284           12
# 4                  wH_Conf_OuHtmlHeader        21           18
# ..                                  ...       ...          ...  ...
# 372          wH_MeshDiary_Configuration         2           12
# 373  wH_Core_PHR_PlannedHospitalization      3233           34
# 374                     wH_Conf_CoreSec         8            7
# 375         wH_DirectTable_C_Scala_ESAS         5           27
# 376       wH_DirectTable_D_DIAGNOSI_ICD         3            5
#
# [377 rows x 4 columns]

# %%
df_cols = pd.DataFrame(data={'cols': [['A', 'B']]})
for idx, row in tinfo.iterrows():
    df_tmp = pd.read_csv(data /f'{row.file_name}.csv', low_memory=False)
    df_cols = df_cols.append({'cols': df_tmp.columns.tolist()}, ignore_index=True)
df_cols = df_cols.drop(df_cols.index[0]).reset_index(drop=True)
df_cols
# Out:
#                                                   cols
# 0     [IDDBType, TypeName, TypeDescriptionName, Order]
# 1    [IDScala_ESAS, Note_Deleted, Author_Insert, Ti...
# 2    [id, Internal_OUCode, Archive_Uri, Access_Cred...
# 3    [IDOperationalUnitAssignation, IDPatientHospit...
# 4    [IDOuHtmlHeader, IDOperationalUnit, IDHospital...
# ..                                                 ...
# 372  [IDConfiguration, GUIDOU, IDDictionary, Second...
# 373  [PhrId, PlannedEntryDate, PlannedPriority, Iss...
# 374  [IDCoreSec, ID_EHR_Definition, Name, Order, Lo...
# 375  [IDScala_ESAS, IDEHR, Author_Insert, TimeStamp...
# 376  [IDDIAGNOSI_ICD, Note_Deleted, Author_Insert, ...
#
# [377 rows x 1 columns]

# %%
# save the tinfo dframe
tinfo['cols'] = df_cols
tinfo.to_csv('./vidas_data/table_cols_info.csv')
tinfo
# Out:
#                               file_name  num_rows  num_columns  \
# 0                        wH_Conf_DBType         7            4
# 1           wH_DirectTable_D_Scala_ESAS         3            5
# 2                  wH_Bck_IsWorking_Bck         1           16
# 3    wH_Core_OperationalUnitAssignation      3284           12
# 4                  wH_Conf_OuHtmlHeader        21           18
# ..                                  ...       ...          ...
# 372          wH_MeshDiary_Configuration         2           12
# 373  wH_Core_PHR_PlannedHospitalization      3233           34
# 374                     wH_Conf_CoreSec         8            7
# 375         wH_DirectTable_C_Scala_ESAS         5           27
# 376       wH_DirectTable_D_DIAGNOSI_ICD         3            5
#
#                                                   cols
# 0     [IDDBType, TypeName, TypeDescriptionName, Order]
# 1    [IDScala_ESAS, Note_Deleted, Author_Insert, Ti...
# 2    [id, Internal_OUCode, Archive_Uri, Access_Cred...
# 3    [IDOperationalUnitAssignation, IDPatientHospit...
# 4    [IDOuHtmlHeader, IDOperationalUnit, IDHospital...
# ..                                                 ...
# 372  [IDConfiguration, GUIDOU, IDDictionary, Second...
# 373  [PhrId, PlannedEntryDate, PlannedPriority, Iss...
# 374  [IDCoreSec, ID_EHR_Definition, Name, Order, Lo...
# 375  [IDScala_ESAS, IDEHR, Author_Insert, TimeStamp...
# 376  [IDDIAGNOSI_ICD, Note_Deleted, Author_Insert, ...
#
# [377 rows x 4 columns]

# %%
# get a one to one translation of every unique column in the data
f_to_col = {}
for idx, e in tinfo.iterrows():
    f_to_col[e.file_name] = (~pd.read_csv(data/f'{e.file_name}.csv', low_memory=False).isna()).sum() if e.num_rows > 0 else None
df = pd.DataFrame(f_to_col).transpose().reset_index()
df.columns = ['file_name'] + list(df.columns[1:])
df
# Out:
#                               file_name  AMT  API_Version  AREADIAGNOSTICA  \
# 0                        wH_Conf_DBType  NaN          NaN              NaN
# 1           wH_DirectTable_D_Scala_ESAS  NaN          NaN              NaN
# 2                  wH_Bck_IsWorking_Bck  NaN          NaN              NaN
# 3    wH_Core_OperationalUnitAssignation  NaN          NaN              NaN
# 4                  wH_Conf_OuHtmlHeader  NaN          NaN              NaN
# ..                                  ...  ...          ...              ...
# 372          wH_MeshDiary_Configuration  NaN          NaN              NaN
# 373  wH_Core_PHR_PlannedHospitalization  NaN          NaN              NaN
# 374                     wH_Conf_CoreSec  NaN          NaN              NaN
# 375         wH_DirectTable_C_Scala_ESAS  NaN          NaN              NaN
# 376       wH_DirectTable_D_DIAGNOSI_ICD  NaN          NaN              NaN
#
#      ASL  ATCCode  ATCDescription  Abbigliamento  Abitazione  AccessId  ...  \
# 0    NaN      NaN             NaN            NaN         NaN       NaN  ...
# 1    NaN      NaN             NaN            NaN         NaN       NaN  ...
# 2    NaN      NaN             NaN            NaN         NaN       NaN  ...
# 3    NaN      NaN             NaN            NaN         NaN       NaN  ...
# 4    NaN      NaN             NaN            NaN         NaN       NaN  ...
# ..   ...      ...             ...            ...         ...       ...  ...
# 372  NaN      NaN             NaN            NaN         NaN       NaN  ...
# 373  NaN      NaN             NaN            NaN         NaN       NaN  ...
# 374  NaN      NaN             NaN            NaN         NaN       NaN  ...
# 375  NaN      NaN             NaN            NaN         NaN       NaN  ...
# 376  NaN      NaN             NaN            NaN         NaN       NaN  ...
#
#      visioni_morte  visioni_vita  volonta  vomito_occasionale  \
# 0              NaN           NaN      NaN                 NaN
# 1              NaN           NaN      NaN                 NaN
# 2              NaN           NaN      NaN                 NaN
# 3              NaN           NaN      NaN                 NaN
# 4              NaN           NaN      NaN                 NaN
# ..             ...           ...      ...                 ...
# 372            NaN           NaN      NaN                 NaN
# 373            NaN           NaN      NaN                 NaN
# 374            NaN           NaN      NaN                 NaN
# 375            NaN           NaN      NaN                 NaN
# 376            NaN           NaN      NaN                 NaN
#
#      vomito_persistente  vulva  wHCode  wHKey  wHRole  wHValue
# 0                   NaN    NaN     NaN    NaN     NaN      NaN
# 1                   NaN    NaN     NaN    NaN     NaN      NaN
# 2                   NaN    NaN     NaN    NaN     NaN      NaN
# 3                   NaN    NaN     NaN    NaN     NaN      NaN
# 4                   NaN    NaN     NaN    NaN     NaN      NaN
# ..                  ...    ...     ...    ...     ...      ...
# 372                 NaN    NaN     NaN    NaN     NaN      NaN
# 373                 NaN    NaN     NaN    NaN     NaN      NaN
# 374                 NaN    NaN     NaN    NaN     NaN      NaN
# 375                 NaN    NaN     NaN    NaN     NaN      NaN
# 376                 NaN    NaN     NaN    NaN     NaN      NaN
#
# [377 rows x 2484 columns]

# %%
# save the dframe giving a cross-tabulation between table name and unique columns
df.to_csv('./vidas_data/cross_ref_cols_tabs.csv', index=False)

# %%
translator = Translator()
df_col_trans = pd.DataFrame({'IT': df.columns.tolist(), 'inter': '', 'EN': ''})
df_col_trans['inter'] = df_col_trans['IT']
df_col_trans['EN'] = df_col_trans['inter'].apply(translator.translate, src='it', dest='en').apply(getattr, args=('text',))
df_col_trans
# Out:
#                    IT            inter               EN
# 0           file_name        file_name        file_name
# 1                 AMT              AMT              AMT
# 2         API_Version      API_Version      API_Version
# 3     AREADIAGNOSTICA  AREADIAGNOSTICA  AREADIAGNOSTICS
# 4                 ASL              ASL              ASL
# ...               ...              ...              ...
# 2479            vulva            vulva            vulva
# 2480           wHCode           wHCode           wHCode
# 2481            wHKey            wHKey            wHKey
# 2482           wHRole           wHRole           wHRole
# 2483          wHValue          wHValue          wHValue
#
# [2484 rows x 3 columns]

# %%
# save the dframe
df_col_trans = df_col_trans.drop(columns='inter')
df_col_trans.to_csv('./vidas_data/col_translated_ref.csv', index=False)

# %%
# translations experiment on drug names
df_main = pd.read_csv('./vidas_data/wH_Therapy_JCM_Therapy.csv')

# %%
df_main.columns
# Out:
# Index(['IDTherapy', 'TherapyType', 'IDCorrelatedTherapy', 'IDEHR',
#        'DateTherapy', 'IDDrug', 'DrugCode', 'DrugXMLIdentifier',
#        'DrugIsAutoVirtual', 'DrugEANCode', 'DrugName', 'ATCCode',
#        'ATCDescription', 'CCTypeOfUsageCode', 'ComplementaryCodeTypeOfUsage',
#        'ComplementaryCodeDoseCode', 'ComplementaryCodeDose',
#        'ActiveIngredientCode', 'ActiveIngredientDescription', 'DrugGrammatura',
#        'DrugShapeDescription', 'DrugPackagingShapeDescription', 'Dose',
#        'DayFrequency', 'HoursString', 'TypeOfUsage', 'DOM', 'ToBeReplanned',
#        'StartTomorrow', 'SuspensionDay', 'MultiDay', 'Immediate',
#        'HasDoseSchema', 'DoseSchemaDescr', 'DoseSchemaXML', 'Note',
#        'Author_Insert', 'TimeStamp_Insert', 'IDDigitalSignDocument'],
#       dtype='object')

# %%
df_main.head()
# Out:
#    IDTherapy TherapyType  IDCorrelatedTherapy  IDEHR              DateTherapy  \
# 0          1    Generica                  NaN      2  2015-01-09 00:00:00.000
# 1          2    Generica                  NaN      2  2015-01-09 00:00:00.000
# 2          3    Generica                  NaN      2  2015-01-09 00:00:00.000
# 3          4    Generica                  NaN      2  2015-01-09 00:00:00.000
# 4          5    Generica                  NaN      2  2015-01-09 00:00:00.000
#
#    IDDrug   DrugCode                                  DrugXMLIdentifier  \
# 0     NaN  024402063  <DrugSearchItem Type="RealDrug" Identifier="10...
# 1     NaN  010089035  <DrugSearchItem Type="RealDrug" Identifier="46...
# 2     NaN  034216186  <DrugSearchItem Type="RealDrug" Identifier="47...
# 3     NaN  020766046  <DrugSearchItem Type="RealDrug" Identifier="72...
# 4     NaN  012745182  <DrugSearchItem Type="RealDrug" Identifier="53...
#
#    DrugIsAutoVirtual  DrugEANCode  ... SuspensionDay MultiDay Immediate  \
# 0              False          NaN  ...         False    False     False
# 1              False          NaN  ...         False    False     False
# 2              False          NaN  ...         False    False     False
# 3              False          NaN  ...         False    False     False
# 4              False          NaN  ...         False    False     False
#
#   HasDoseSchema DoseSchemaDescr DoseSchemaXML                 Note  \
# 0         False         125 mcg           NaN  dal 12 gennaio 2015
# 1         False           25 mg           NaN  dal 12 gennaio 2015
# 2         False           20 mg           NaN  dal 12 gennaio 2015
# 3         False           10 mg           NaN  dal 12 gennaio 2015
# 4         False             1 g           NaN  dal 12 gennaio 2015
#
#                            Author_Insert         TimeStamp_Insert  \
# 0  Lonati Giada Carla - LNTGCR68S56F205H  2015-01-09 16:06:16.677
# 1  Lonati Giada Carla - LNTGCR68S56F205H  2015-01-09 16:06:16.677
# 2  Lonati Giada Carla - LNTGCR68S56F205H  2015-01-09 16:06:16.677
# 3  Lonati Giada Carla - LNTGCR68S56F205H  2015-01-09 16:06:16.677
# 4  Lonati Giada Carla - LNTGCR68S56F205H  2015-01-09 16:06:16.677
#
#   IDDigitalSignDocument
# 0                  1185
# 1                  1186
# 2                  1187
# 3                  1188
# 4                  1189
#
# [5 rows x 39 columns]

# %%
df_main.DrugName.value_counts()
# Out:
# SOLDESAM              18257
# MORFINA CL MOLT.      13413
# SERENASE              11092
# LASIX                 10021
# MOVICOL                9106
#                       ...
# FLIXOTIDE DISK 500        1
# CEFTRIAXONE KABI          1
# MORFINA CL MONICO         1
# ONDANSETRONE MGI          1
# EXEMESTANE TEVA           1
# Name: DrugName, Length: 1214, dtype: int64

# %%
df_drug = df_main[['IDEHR', 'DateTherapy', 'DrugName', 'ActiveIngredientDescription', 'Dose']]
df_drug.head(20)
# Out:
#     IDEHR              DateTherapy                 DrugName  \
# 0       2  2015-01-09 00:00:00.000                  EUTIROX
# 1       2  2015-01-09 00:00:00.000             DELTACORTENE
# 2       2  2015-01-09 00:00:00.000                   PARIET
# 3       2  2015-01-09 00:00:00.000                   PLASIL
# 4       2  2015-01-09 00:00:00.000              TACHIPIRINA
# 5       2  2015-01-09 00:00:00.000                  TRIATEC
# 6       2  2015-01-09 00:00:00.000           MIRTAZAPINA EG
# 7       2  2015-01-09 00:00:00.000                  MOVICOL
# 8       2  2015-01-09 00:00:00.000                PURSENNID
# 9    1020  2015-01-10 00:00:00.000          OMEPRAZOLO TEVA
# 10   1020  2015-01-10 00:00:00.000                 SOLDESAM
# 11   1020  2015-01-10 00:00:00.000            CARDIOASPIRIN
# 12   1020  2015-01-10 00:00:00.000                 NOVONORM
# 13   1020  2015-01-10 00:00:00.000             COEFFERALGAN
# 14   1020  2015-01-10 00:00:00.000                   PLASIL
# 15   1020  2015-01-10 00:00:00.000                VERTISERC
# 16   1020  2015-01-10 00:00:00.000                    TAVOR
# 17   1020  2015-01-10 00:00:00.000                    LASIX
# 18   1020  2015-01-12 00:00:00.000  AMOXICILLINA AC CLA RAT
# 19   1020  2015-01-13 00:00:00.000  AMOXICILLINA AC CLA RAT
#
#                           ActiveIngredientDescription     Dose
# 0                                 LEVOTIROXINA SODICA  125 mcg
# 1                                          PREDNISONE    25 mg
# 2                                  RABEPRAZOLO SODICO    20 mg
# 3                           METOCLOPRAMIDE CLORIDRATO    10 mg
# 4                                        PARACETAMOLO      1 g
# 5                                            RAMIPRIL   2.5 mg
# 6                                         MIRTAZAPINA    15 mg
# 7   POTASSIO CLORURO\SODIO CLORURO\SODIO BICARBONA...      1 b
# 8                       SENNA FOGLIA (GLUCOSIDI PURI)    1 cpr
# 9                                          OMEPRAZOLO    20 mg
# 10                        DESAMETASONE FOSFATO SODICO   64 gtt
# 11                             ACIDO ACETILSALICILICO   100 mg
# 12                                        REPAGLINIDE     2 mg
# 13                       CODEINA FOSFATO\PARACETAMOLO      1 c
# 14                          METOCLOPRAMIDE CLORIDRATO    10 mg
# 15                            BETAISTINA DICLORIDRATO     4 mg
# 16                                          LORAZEPAM     1 mg
# 17                                         FUROSEMIDE    25 mg
# 18                     AMOXICILLINA\ACIDO CLAVULANICO      1 g
# 19                     AMOXICILLINA\ACIDO CLAVULANICO      1 g

# %%
df_tmp = df_drug[0:2000]
df_tmp
# Out:
#       IDEHR              DateTherapy      DrugName  \
# 0         2  2015-01-09 00:00:00.000       EUTIROX
# 1         2  2015-01-09 00:00:00.000  DELTACORTENE
# 2         2  2015-01-09 00:00:00.000        PARIET
# 3         2  2015-01-09 00:00:00.000        PLASIL
# 4         2  2015-01-09 00:00:00.000   TACHIPIRINA
# ...     ...                      ...           ...
# 1995   1019  2015-02-02 00:00:00.000      DIFLUCAN
# 1996   1043  2015-01-24 00:00:00.000      BUSCOPAN
# 1997   1043  2015-01-24 00:00:00.000      SERENASE
# 1998   1043  2015-01-24 00:00:00.000        UGUROL
# 1999   1043  2015-01-24 00:00:00.000     HUMULIN R
#
#      ActiveIngredientDescription     Dose
# 0            LEVOTIROXINA SODICA  125 mcg
# 1                     PREDNISONE    25 mg
# 2             RABEPRAZOLO SODICO    20 mg
# 3      METOCLOPRAMIDE CLORIDRATO    10 mg
# 4                   PARACETAMOLO      1 g
# ...                          ...      ...
# 1995                 FLUCONAZOLO   200 mg
# 1996    SCOPOLAMINA BUTILBROMURO    20 mg
# 1997                 ALOPERIDOLO     2 mg
# 1998           ACIDO TRANEXAMICO   500 mg
# 1999              INSULINA UMANA        0
#
# [2000 rows x 5 columns]

# %%
# checking for NaNs
print(sum(df_tmp.DrugName.isna()))
print(sum(df_tmp.ActiveIngredientDescription.isna()))
# Out:
# 0
# 33

# %%
df_tmp['DrugName_Translated'] = df_tmp['DrugName'].apply(translator.translate, src='it', dest='en').apply(getattr, args=('text',))
df_tmp
# Out:
# <ipython-input-12-f8760f8fbb42>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp['DrugName_Translated'] = df_tmp['DrugName'].apply(translator.translate, src='it', dest='en').apply(getattr, args=('text',))
#       IDEHR              DateTherapy      DrugName  \
# 0         2  2015-01-09 00:00:00.000       EUTIROX
# 1         2  2015-01-09 00:00:00.000  DELTACORTENE
# 2         2  2015-01-09 00:00:00.000        PARIET
# 3         2  2015-01-09 00:00:00.000        PLASIL
# 4         2  2015-01-09 00:00:00.000   TACHIPIRINA
# ...     ...                      ...           ...
# 1995   1019  2015-02-02 00:00:00.000      DIFLUCAN
# 1996   1043  2015-01-24 00:00:00.000      BUSCOPAN
# 1997   1043  2015-01-24 00:00:00.000      SERENASE
# 1998   1043  2015-01-24 00:00:00.000        UGUROL
# 1999   1043  2015-01-24 00:00:00.000     HUMULIN R
#
#      ActiveIngredientDescription     Dose DrugName_Translated
# 0            LEVOTIROXINA SODICA  125 mcg             EUTIROX
# 1                     PREDNISONE    25 mg        DELTACORTENE
# 2             RABEPRAZOLO SODICO    20 mg              PARIET
# 3      METOCLOPRAMIDE CLORIDRATO    10 mg              PLASIL
# 4                   PARACETAMOLO      1 g         TACHIPIRINA
# ...                          ...      ...                 ...
# 1995                 FLUCONAZOLO   200 mg            DIFLUCAN
# 1996    SCOPOLAMINA BUTILBROMURO    20 mg            BUSCOPAN
# 1997                 ALOPERIDOLO     2 mg            SERENASE
# 1998           ACIDO TRANEXAMICO   500 mg              UGUROL
# 1999              INSULINA UMANA        0           HUMULIN R
#
# [2000 rows x 6 columns]

# %%
df_tmp['ActiveIng_Translated'] = df_tmp['ActiveIngredientDescription'].dropna().apply(translator.translate, src='it', dest='en').apply(getattr, args=('text',))
df_tmp
# Out:
# <ipython-input-13-911514a234ea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp['ActiveIng_Translated'] = df_tmp['ActiveIngredientDescription'].dropna().apply(translator.translate, src='it', dest='en').apply(getattr, args=('text',))
#       IDEHR              DateTherapy      DrugName  \
# 0         2  2015-01-09 00:00:00.000       EUTIROX
# 1         2  2015-01-09 00:00:00.000  DELTACORTENE
# 2         2  2015-01-09 00:00:00.000        PARIET
# 3         2  2015-01-09 00:00:00.000        PLASIL
# 4         2  2015-01-09 00:00:00.000   TACHIPIRINA
# ...     ...                      ...           ...
# 1995   1019  2015-02-02 00:00:00.000      DIFLUCAN
# 1996   1043  2015-01-24 00:00:00.000      BUSCOPAN
# 1997   1043  2015-01-24 00:00:00.000      SERENASE
# 1998   1043  2015-01-24 00:00:00.000        UGUROL
# 1999   1043  2015-01-24 00:00:00.000     HUMULIN R
#
#      ActiveIngredientDescription     Dose DrugName_Translated  \
# 0            LEVOTIROXINA SODICA  125 mcg             EUTIROX
# 1                     PREDNISONE    25 mg        DELTACORTENE
# 2             RABEPRAZOLO SODICO    20 mg              PARIET
# 3      METOCLOPRAMIDE CLORIDRATO    10 mg              PLASIL
# 4                   PARACETAMOLO      1 g         TACHIPIRINA
# ...                          ...      ...                 ...
# 1995                 FLUCONAZOLO   200 mg            DIFLUCAN
# 1996    SCOPOLAMINA BUTILBROMURO    20 mg            BUSCOPAN
# 1997                 ALOPERIDOLO     2 mg            SERENASE
# 1998           ACIDO TRANEXAMICO   500 mg              UGUROL
# 1999              INSULINA UMANA        0           HUMULIN R
#
#               ActiveIng_Translated
# 0              LEVOTHYROXIN SODIUM
# 1                       PREDNISONE
# 2               RABEPRAZOLE SODIUM
# 3     METOCLOPRAMIDE HYDROCHLORIDE
# 4                      PARACETAMOL
# ...                            ...
# 1995                   FLUCONAZOLE
# 1996      SCOPOLAMINA BUTYLBROMIDE
# 1997                   ALOPERIDOLO
# 1998               TRANEXAMIC ACID
# 1999                 HUMAN INSULIN
#
# [2000 rows x 7 columns]

# %%
df_drug.shape
# Out:
# (292176, 5)

# %%
# df_drug['DrugName_Translated'] = df_drug['DrugName'].apply(translator.translate, src='it', dest='en').apply(getattr, args=('text',))
df_drug.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-b6ed9ef7caea> in <module>
#       1 # df_drug['DrugName_Translated'] = df_drug['DrugName'].apply(translator.translate, src='it', dest='en').apply(getattr, args=('text',))
# ----> 2 df_drug.head(10)
#
# NameError: name 'df_drug' is not defined

# %%
df_drug['ActiveIng_Translated'] = df_drug['ActiveIngredientDescription'].dropna().apply(translator.translate, src='it', dest='en').apply(getattr, args=('text',))
df_drug.head(10)

# %%
df_drug.to_pickle('./hospiedata/drug_trans.csv')
