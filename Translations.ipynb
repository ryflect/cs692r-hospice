# %%
import numpy as np
import pandas as pd
from googletrans import Translator

# %%
df_main = pd.read_csv('./vidas_data/wH_Therapy_JCM_Therapy.csv')

# %%
df_main.columns
# Out:
# Index(['IDTherapy', 'TherapyType', 'IDCorrelatedTherapy', 'IDEHR',
#        'DateTherapy', 'IDDrug', 'DrugCode', 'DrugXMLIdentifier',
#        'DrugIsAutoVirtual', 'DrugEANCode', 'DrugName', 'ATCCode',
#        'ATCDescription', 'CCTypeOfUsageCode', 'ComplementaryCodeTypeOfUsage',
#        'ComplementaryCodeDoseCode', 'ComplementaryCodeDose',
#        'ActiveIngredientCode', 'ActiveIngredientDescription', 'DrugGrammatura',
#        'DrugShapeDescription', 'DrugPackagingShapeDescription', 'Dose',
#        'DayFrequency', 'HoursString', 'TypeOfUsage', 'DOM', 'ToBeReplanned',
#        'StartTomorrow', 'SuspensionDay', 'MultiDay', 'Immediate',
#        'HasDoseSchema', 'DoseSchemaDescr', 'DoseSchemaXML', 'Note',
#        'Author_Insert', 'TimeStamp_Insert', 'IDDigitalSignDocument'],
#       dtype='object')

# %%
df_main.head()
# Out:
#    IDTherapy TherapyType  IDCorrelatedTherapy  IDEHR              DateTherapy  \
# 0          1    Generica                  NaN      2  2015-01-09 00:00:00.000
# 1          2    Generica                  NaN      2  2015-01-09 00:00:00.000
# 2          3    Generica                  NaN      2  2015-01-09 00:00:00.000
# 3          4    Generica                  NaN      2  2015-01-09 00:00:00.000
# 4          5    Generica                  NaN      2  2015-01-09 00:00:00.000
#
#    IDDrug   DrugCode                                  DrugXMLIdentifier  \
# 0     NaN  024402063  <DrugSearchItem Type="RealDrug" Identifier="10...
# 1     NaN  010089035  <DrugSearchItem Type="RealDrug" Identifier="46...
# 2     NaN  034216186  <DrugSearchItem Type="RealDrug" Identifier="47...
# 3     NaN  020766046  <DrugSearchItem Type="RealDrug" Identifier="72...
# 4     NaN  012745182  <DrugSearchItem Type="RealDrug" Identifier="53...
#
#    DrugIsAutoVirtual  DrugEANCode  ... SuspensionDay MultiDay Immediate  \
# 0              False          NaN  ...         False    False     False
# 1              False          NaN  ...         False    False     False
# 2              False          NaN  ...         False    False     False
# 3              False          NaN  ...         False    False     False
# 4              False          NaN  ...         False    False     False
#
#   HasDoseSchema DoseSchemaDescr DoseSchemaXML                 Note  \
# 0         False         125 mcg           NaN  dal 12 gennaio 2015
# 1         False           25 mg           NaN  dal 12 gennaio 2015
# 2         False           20 mg           NaN  dal 12 gennaio 2015
# 3         False           10 mg           NaN  dal 12 gennaio 2015
# 4         False             1 g           NaN  dal 12 gennaio 2015
#
#                            Author_Insert         TimeStamp_Insert  \
# 0  Lonati Giada Carla - LNTGCR68S56F205H  2015-01-09 16:06:16.677
# 1  Lonati Giada Carla - LNTGCR68S56F205H  2015-01-09 16:06:16.677
# 2  Lonati Giada Carla - LNTGCR68S56F205H  2015-01-09 16:06:16.677
# 3  Lonati Giada Carla - LNTGCR68S56F205H  2015-01-09 16:06:16.677
# 4  Lonati Giada Carla - LNTGCR68S56F205H  2015-01-09 16:06:16.677
#
#   IDDigitalSignDocument
# 0                  1185
# 1                  1186
# 2                  1187
# 3                  1188
# 4                  1189
#
# [5 rows x 39 columns]

# %%
df_main.DrugName.value_counts()
# Out:
# SOLDESAM                     18257
# MORFINA CL MOLT.             13413
# SERENASE                     11092
# LASIX                        10021
# MOVICOL                       9106
#                              ...
# FORADIL                          1
# CEFTRIAXONE KABI                 1
# SODIO CLORURO 20% 5F 10ML        1
# PROPOFOL B.BRAUN 1%              1
# INDOXEN                          1
# Name: DrugName, Length: 1214, dtype: int64

# %%
df_drug = df_main[['IDEHR', 'DateTherapy', 'DrugName', 'ActiveIngredientDescription', 'Dose']]
df_drug.head(20)
# Out:
#     IDEHR              DateTherapy                 DrugName  \
# 0       2  2015-01-09 00:00:00.000                  EUTIROX
# 1       2  2015-01-09 00:00:00.000             DELTACORTENE
# 2       2  2015-01-09 00:00:00.000                   PARIET
# 3       2  2015-01-09 00:00:00.000                   PLASIL
# 4       2  2015-01-09 00:00:00.000              TACHIPIRINA
# 5       2  2015-01-09 00:00:00.000                  TRIATEC
# 6       2  2015-01-09 00:00:00.000           MIRTAZAPINA EG
# 7       2  2015-01-09 00:00:00.000                  MOVICOL
# 8       2  2015-01-09 00:00:00.000                PURSENNID
# 9    1020  2015-01-10 00:00:00.000          OMEPRAZOLO TEVA
# 10   1020  2015-01-10 00:00:00.000                 SOLDESAM
# 11   1020  2015-01-10 00:00:00.000            CARDIOASPIRIN
# 12   1020  2015-01-10 00:00:00.000                 NOVONORM
# 13   1020  2015-01-10 00:00:00.000             COEFFERALGAN
# 14   1020  2015-01-10 00:00:00.000                   PLASIL
# 15   1020  2015-01-10 00:00:00.000                VERTISERC
# 16   1020  2015-01-10 00:00:00.000                    TAVOR
# 17   1020  2015-01-10 00:00:00.000                    LASIX
# 18   1020  2015-01-12 00:00:00.000  AMOXICILLINA AC CLA RAT
# 19   1020  2015-01-13 00:00:00.000  AMOXICILLINA AC CLA RAT
#
#                           ActiveIngredientDescription     Dose
# 0                                 LEVOTIROXINA SODICA  125 mcg
# 1                                          PREDNISONE    25 mg
# 2                                  RABEPRAZOLO SODICO    20 mg
# 3                           METOCLOPRAMIDE CLORIDRATO    10 mg
# 4                                        PARACETAMOLO      1 g
# 5                                            RAMIPRIL   2.5 mg
# 6                                         MIRTAZAPINA    15 mg
# 7   POTASSIO CLORURO\SODIO CLORURO\SODIO BICARBONA...      1 b
# 8                       SENNA FOGLIA (GLUCOSIDI PURI)    1 cpr
# 9                                          OMEPRAZOLO    20 mg
# 10                        DESAMETASONE FOSFATO SODICO   64 gtt
# 11                             ACIDO ACETILSALICILICO   100 mg
# 12                                        REPAGLINIDE     2 mg
# 13                       CODEINA FOSFATO\PARACETAMOLO      1 c
# 14                          METOCLOPRAMIDE CLORIDRATO    10 mg
# 15                            BETAISTINA DICLORIDRATO     4 mg
# 16                                          LORAZEPAM     1 mg
# 17                                         FUROSEMIDE    25 mg
# 18                     AMOXICILLINA\ACIDO CLAVULANICO      1 g
# 19                     AMOXICILLINA\ACIDO CLAVULANICO      1 g

# %%
df_tmp = df_drug[0:20]
df_tmp
# Out:
#     IDEHR              DateTherapy                 DrugName  \
# 0       2  2015-01-09 00:00:00.000                  EUTIROX
# 1       2  2015-01-09 00:00:00.000             DELTACORTENE
# 2       2  2015-01-09 00:00:00.000                   PARIET
# 3       2  2015-01-09 00:00:00.000                   PLASIL
# 4       2  2015-01-09 00:00:00.000              TACHIPIRINA
# 5       2  2015-01-09 00:00:00.000                  TRIATEC
# 6       2  2015-01-09 00:00:00.000           MIRTAZAPINA EG
# 7       2  2015-01-09 00:00:00.000                  MOVICOL
# 8       2  2015-01-09 00:00:00.000                PURSENNID
# 9    1020  2015-01-10 00:00:00.000          OMEPRAZOLO TEVA
# 10   1020  2015-01-10 00:00:00.000                 SOLDESAM
# 11   1020  2015-01-10 00:00:00.000            CARDIOASPIRIN
# 12   1020  2015-01-10 00:00:00.000                 NOVONORM
# 13   1020  2015-01-10 00:00:00.000             COEFFERALGAN
# 14   1020  2015-01-10 00:00:00.000                   PLASIL
# 15   1020  2015-01-10 00:00:00.000                VERTISERC
# 16   1020  2015-01-10 00:00:00.000                    TAVOR
# 17   1020  2015-01-10 00:00:00.000                    LASIX
# 18   1020  2015-01-12 00:00:00.000  AMOXICILLINA AC CLA RAT
# 19   1020  2015-01-13 00:00:00.000  AMOXICILLINA AC CLA RAT
#
#                           ActiveIngredientDescription     Dose
# 0                                 LEVOTIROXINA SODICA  125 mcg
# 1                                          PREDNISONE    25 mg
# 2                                  RABEPRAZOLO SODICO    20 mg
# 3                           METOCLOPRAMIDE CLORIDRATO    10 mg
# 4                                        PARACETAMOLO      1 g
# 5                                            RAMIPRIL   2.5 mg
# 6                                         MIRTAZAPINA    15 mg
# 7   POTASSIO CLORURO\SODIO CLORURO\SODIO BICARBONA...      1 b
# 8                       SENNA FOGLIA (GLUCOSIDI PURI)    1 cpr
# 9                                          OMEPRAZOLO    20 mg
# 10                        DESAMETASONE FOSFATO SODICO   64 gtt
# 11                             ACIDO ACETILSALICILICO   100 mg
# 12                                        REPAGLINIDE     2 mg
# 13                       CODEINA FOSFATO\PARACETAMOLO      1 c
# 14                          METOCLOPRAMIDE CLORIDRATO    10 mg
# 15                            BETAISTINA DICLORIDRATO     4 mg
# 16                                          LORAZEPAM     1 mg
# 17                                         FUROSEMIDE    25 mg
# 18                     AMOXICILLINA\ACIDO CLAVULANICO      1 g
# 19                     AMOXICILLINA\ACIDO CLAVULANICO      1 g

# %%
translator = Translator()
df_tmp['DrugName_Translated'] = df_tmp['DrugName'].apply(translator.translate, src='it', dest='en').apply(getattr, args=('text',))
df_tmp
# Out:
# <ipython-input-14-f8760f8fbb42>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp['DrugName_Translated'] = df_tmp['DrugName'].apply(translator.translate, src='it', dest='en').apply(getattr, args=('text',))
#     IDEHR              DateTherapy                 DrugName  \
# 0       2  2015-01-09 00:00:00.000                  EUTIROX
# 1       2  2015-01-09 00:00:00.000             DELTACORTENE
# 2       2  2015-01-09 00:00:00.000                   PARIET
# 3       2  2015-01-09 00:00:00.000                   PLASIL
# 4       2  2015-01-09 00:00:00.000              TACHIPIRINA
# 5       2  2015-01-09 00:00:00.000                  TRIATEC
# 6       2  2015-01-09 00:00:00.000           MIRTAZAPINA EG
# 7       2  2015-01-09 00:00:00.000                  MOVICOL
# 8       2  2015-01-09 00:00:00.000                PURSENNID
# 9    1020  2015-01-10 00:00:00.000          OMEPRAZOLO TEVA
# 10   1020  2015-01-10 00:00:00.000                 SOLDESAM
# 11   1020  2015-01-10 00:00:00.000            CARDIOASPIRIN
# 12   1020  2015-01-10 00:00:00.000                 NOVONORM
# 13   1020  2015-01-10 00:00:00.000             COEFFERALGAN
# 14   1020  2015-01-10 00:00:00.000                   PLASIL
# 15   1020  2015-01-10 00:00:00.000                VERTISERC
# 16   1020  2015-01-10 00:00:00.000                    TAVOR
# 17   1020  2015-01-10 00:00:00.000                    LASIX
# 18   1020  2015-01-12 00:00:00.000  AMOXICILLINA AC CLA RAT
# 19   1020  2015-01-13 00:00:00.000  AMOXICILLINA AC CLA RAT
#
#                           ActiveIngredientDescription     Dose  \
# 0                                 LEVOTIROXINA SODICA  125 mcg
# 1                                          PREDNISONE    25 mg
# 2                                  RABEPRAZOLO SODICO    20 mg
# 3                           METOCLOPRAMIDE CLORIDRATO    10 mg
# 4                                        PARACETAMOLO      1 g
# 5                                            RAMIPRIL   2.5 mg
# 6                                         MIRTAZAPINA    15 mg
# 7   POTASSIO CLORURO\SODIO CLORURO\SODIO BICARBONA...      1 b
# 8                       SENNA FOGLIA (GLUCOSIDI PURI)    1 cpr
# 9                                          OMEPRAZOLO    20 mg
# 10                        DESAMETASONE FOSFATO SODICO   64 gtt
# 11                             ACIDO ACETILSALICILICO   100 mg
# 12                                        REPAGLINIDE     2 mg
# 13                       CODEINA FOSFATO\PARACETAMOLO      1 c
# 14                          METOCLOPRAMIDE CLORIDRATO    10 mg
# 15                            BETAISTINA DICLORIDRATO     4 mg
# 16                                          LORAZEPAM     1 mg
# 17                                         FUROSEMIDE    25 mg
# 18                     AMOXICILLINA\ACIDO CLAVULANICO      1 g
# 19                     AMOXICILLINA\ACIDO CLAVULANICO      1 g
#
#        DrugName_Translated
# 0                  EUTIROX
# 1             DELTACORTENE
# 2                   PARIET
# 3                   PLASIL
# 4              TACHIPIRINA
# 5                  TRIATEC
# 6           Mirtazapine EG
# 7                  MOVICOL
# 8                PURSENNID
# 9          OMEPRAZOLE TEVA
# 10                SOLDESAM
# 11           CARDIOASPIRIN
# 12                NOVONORM
# 13            COEFFERALGAN
# 14                  PLASIL
# 15               VERTISERC
# 16                   TAVOR
# 17                   LASIX
# 18  AMOXICILLIN AC CLA RAT
# 19  AMOXICILLIN AC CLA RAT

# %%
df_tmp['ActiveIng_Translated'] = df_tmp['ActiveIngredientDescription'].apply(translator.translate, src='it', dest='en').apply(getattr, args=('text',))
df_tmp
# Out:
# <ipython-input-15-5e05cf3f304b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp['ActiveIng_Translated'] = df_tmp['ActiveIngredientDescription'].apply(translator.translate, src='it', dest='en').apply(getattr, args=('text',))
#     IDEHR              DateTherapy                 DrugName  \
# 0       2  2015-01-09 00:00:00.000                  EUTIROX
# 1       2  2015-01-09 00:00:00.000             DELTACORTENE
# 2       2  2015-01-09 00:00:00.000                   PARIET
# 3       2  2015-01-09 00:00:00.000                   PLASIL
# 4       2  2015-01-09 00:00:00.000              TACHIPIRINA
# 5       2  2015-01-09 00:00:00.000                  TRIATEC
# 6       2  2015-01-09 00:00:00.000           MIRTAZAPINA EG
# 7       2  2015-01-09 00:00:00.000                  MOVICOL
# 8       2  2015-01-09 00:00:00.000                PURSENNID
# 9    1020  2015-01-10 00:00:00.000          OMEPRAZOLO TEVA
# 10   1020  2015-01-10 00:00:00.000                 SOLDESAM
# 11   1020  2015-01-10 00:00:00.000            CARDIOASPIRIN
# 12   1020  2015-01-10 00:00:00.000                 NOVONORM
# 13   1020  2015-01-10 00:00:00.000             COEFFERALGAN
# 14   1020  2015-01-10 00:00:00.000                   PLASIL
# 15   1020  2015-01-10 00:00:00.000                VERTISERC
# 16   1020  2015-01-10 00:00:00.000                    TAVOR
# 17   1020  2015-01-10 00:00:00.000                    LASIX
# 18   1020  2015-01-12 00:00:00.000  AMOXICILLINA AC CLA RAT
# 19   1020  2015-01-13 00:00:00.000  AMOXICILLINA AC CLA RAT
#
#                           ActiveIngredientDescription     Dose  \
# 0                                 LEVOTIROXINA SODICA  125 mcg
# 1                                          PREDNISONE    25 mg
# 2                                  RABEPRAZOLO SODICO    20 mg
# 3                           METOCLOPRAMIDE CLORIDRATO    10 mg
# 4                                        PARACETAMOLO      1 g
# 5                                            RAMIPRIL   2.5 mg
# 6                                         MIRTAZAPINA    15 mg
# 7   POTASSIO CLORURO\SODIO CLORURO\SODIO BICARBONA...      1 b
# 8                       SENNA FOGLIA (GLUCOSIDI PURI)    1 cpr
# 9                                          OMEPRAZOLO    20 mg
# 10                        DESAMETASONE FOSFATO SODICO   64 gtt
# 11                             ACIDO ACETILSALICILICO   100 mg
# 12                                        REPAGLINIDE     2 mg
# 13                       CODEINA FOSFATO\PARACETAMOLO      1 c
# 14                          METOCLOPRAMIDE CLORIDRATO    10 mg
# 15                            BETAISTINA DICLORIDRATO     4 mg
# 16                                          LORAZEPAM     1 mg
# 17                                         FUROSEMIDE    25 mg
# 18                     AMOXICILLINA\ACIDO CLAVULANICO      1 g
# 19                     AMOXICILLINA\ACIDO CLAVULANICO      1 g
#
#        DrugName_Translated                               ActiveIng_Translated
# 0                  EUTIROX                                LEVOTHYROXIN SODIUM
# 1             DELTACORTENE                                         PREDNISONE
# 2                   PARIET                                 RABEPRAZOLE SODIUM
# 3                   PLASIL                       METOCLOPRAMIDE HYDROCHLORIDE
# 4              TACHIPIRINA                                        PARACETAMOL
# 5                  TRIATEC                                           RAMIPRIL
# 6           Mirtazapine EG                                        MIRTAZAPINA
# 7                  MOVICOL  POTASSIUM CHLORIDE \ SODIUM CHLORIDE \ SODIUM ...
# 8                PURSENNID                       SENNA LEAF (PURE GLUCOSIDES)
# 9          OMEPRAZOLE TEVA                                         OMEPRAZOLE
# 10                SOLDESAM                     DESAMETHASONE SODIUM PHOSPHATE
# 11           CARDIOASPIRIN                               ACETYLSALICYLIC ACID
# 12                NOVONORM                                        REPAGLINIDE
# 13            COEFFERALGAN                     CODEIN PHOSPHATE \ PARACETAMOL
# 14                  PLASIL                       METOCLOPRAMIDE HYDROCHLORIDE
# 15               VERTISERC                         BETAHISTINE DICHLORHYDRATE
# 16                   TAVOR                                          LORAZEPAM
# 17                   LASIX                                         FUROSEMIDE
# 18  AMOXICILLIN AC CLA RAT                      AMOXICILLIN \ CLAVULANIC ACID
# 19  AMOXICILLIN AC CLA RAT                      AMOXICILLIN \ CLAVULANIC ACID

# %%
df_drug.shape
# Out:
# (292176, 5)

# %%
df_drug['DrugName_Translated'] = df_drug['DrugName'].apply(translator.translate, src='it', dest='en').apply(getattr, args=('text',))
df_drug.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-d91815e43fc3> in <module>
# ----> 1 df_drug['DrugName_Translated'] = df_drug['DrugName'].apply(translator.translate, src='it', dest='en').apply(getattr, args=('text',))
#       2 df_drug.head(10)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in f(x)
#    3831
#    3832             def f(x):
# -> 3833                 return func(x, *args, **kwds)
#    3834
#    3835         else:
#
# ~\anaconda3\lib\site-packages\googletrans\client.py in translate(self, text, dest, src, **kwargs)
#     180
#     181         origin = text
# --> 182         data = self._translate(text, dest, src, kwargs)
#     183
#     184         # this code will be updated when the format is changed.
#
# ~\anaconda3\lib\site-packages\googletrans\client.py in _translate(self, text, dest, src, override)
#      81
#      82         url = urls.TRANSLATE.format(host=self._pick_service_url())
# ---> 83         r = self.client.get(url, params=params)
#      84
#      85         if r.status_code == 200:
#
# ~\anaconda3\lib\site-packages\httpx\_client.py in get(self, url, params, headers, cookies, auth, allow_redirects, timeout)
#     753         timeout: typing.Union[TimeoutTypes, UnsetType] = UNSET,
#     754     ) -> Response:
# --> 755         return self.request(
#     756             "GET",
#     757             url,
#
# ~\anaconda3\lib\site-packages\httpx\_client.py in request(self, method, url, data, files, json, params, headers, cookies, auth, allow_redirects, timeout)
#     598             cookies=cookies,
#     599         )
# --> 600         return self.send(
#     601             request, auth=auth, allow_redirects=allow_redirects, timeout=timeout,
#     602         )
#
# ~\anaconda3\lib\site-packages\httpx\_client.py in send(self, request, stream, auth, allow_redirects, timeout)
#     618         auth = self.build_auth(request, auth)
#     619
# --> 620         response = self.send_handling_redirects(
#     621             request, auth=auth, timeout=timeout, allow_redirects=allow_redirects,
#     622         )
#
# ~\anaconda3\lib\site-packages\httpx\_client.py in send_handling_redirects(self, request, auth, timeout, allow_redirects, history)
#     645                 raise TooManyRedirects()
#     646
# --> 647             response = self.send_handling_auth(
#     648                 request, auth=auth, timeout=timeout, history=history
#     649             )
#
# ~\anaconda3\lib\site-packages\httpx\_client.py in send_handling_auth(self, request, history, auth, timeout)
#     682         request = next(auth_flow)
#     683         while True:
# --> 684             response = self.send_single_request(request, timeout)
#     685             if auth.requires_response_body:
#     686                 response.read()
#
# ~\anaconda3\lib\site-packages\httpx\_client.py in send_single_request(self, request, timeout)
#     712                 headers,
#     713                 stream,
# --> 714             ) = transport.request(
#     715                 request.method.encode(),
#     716                 request.url.raw,
#
# ~\anaconda3\lib\site-packages\httpcore\_sync\connection_pool.py in request(self, method, url, headers, stream, timeout)
#     150
#     151             try:
# --> 152                 response = connection.request(
#     153                     method, url, headers=headers, stream=stream, timeout=timeout
#     154                 )
#
# ~\anaconda3\lib\site-packages\httpcore\_sync\connection.py in request(self, method, url, headers, stream, timeout)
#      76             "connection.request method=%r url=%r headers=%r", method, url, headers
#      77         )
# ---> 78         return self.connection.request(method, url, headers, stream, timeout)
#      79
#      80     def _open_socket(self, timeout: TimeoutDict = None) -> SyncSocketStream:
#
# ~\anaconda3\lib\site-packages\httpcore\_sync\http11.py in request(self, method, url, headers, stream, timeout)
#      60             reason_phrase,
#      61             headers,
# ---> 62         ) = self._receive_response(timeout)
#      63         stream = SyncByteStream(
#      64             iterator=self._receive_response_data(timeout),
#
# ~\anaconda3\lib\site-packages\httpcore\_sync\http11.py in _receive_response(self, timeout)
#     113         """
#     114         while True:
# --> 115             event = self._receive_event(timeout)
#     116             if isinstance(event, h11.Response):
#     117                 break
#
# ~\anaconda3\lib\site-packages\httpcore\_sync\http11.py in _receive_event(self, timeout)
#     143
#     144             if event is h11.NEED_DATA:
# --> 145                 data = self.socket.read(self.READ_NUM_BYTES, timeout)
#     146                 self.h11_state.receive_data(data)
#     147             else:
#
# ~\anaconda3\lib\site-packages\httpcore\_backends\sync.py in read(self, n, timeout)
#      60             with map_exceptions(exc_map):
#      61                 self.sock.settimeout(read_timeout)
# ---> 62                 return self.sock.recv(n)
#      63
#      64     def write(self, data: bytes, timeout: TimeoutDict) -> None:
#
# ~\anaconda3\lib\ssl.py in recv(self, buflen, flags)
#    1224                     "non-zero flags not allowed in calls to recv() on %s" %
#    1225                     self.__class__)
# -> 1226             return self.read(buflen)
#    1227         else:
#    1228             return super().recv(buflen, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1099                 return self._sslobj.read(len, buffer)
#    1100             else:
# -> 1101                 return self._sslobj.read(len)
#    1102         except SSLError as x:
#    1103             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
df_drug['ActiveIng_Translated'] = df_drug['ActiveIngredientDescription'].apply(translator.translate, src='it', dest='en').apply(getattr, args=('text',))
df_drug.head(10)

# %%
df_drug.to_pickle('./hospiedata/drug_trans.csv')
